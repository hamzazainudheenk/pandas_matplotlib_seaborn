# %%
#complex numbers
x=3+1j
com=1+0j
print(com)
print(x)

print(type(x))
print(type(com))
# Out:
# (1+0j)
# (3+1j)
# <class 'complex'>
# <class 'complex'>

# %%
x=None
print(x)

print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
s1="hello"
s2="world"
s3='''this is a 
multi-line 
string'''
print(s1,s2)
print(s1+s2)
print(s3)
s2[3]
s3[2:1:2]
# Out:
# hello world
# helloworld
# this is a
# multi-line
# string
# ''

# %%
s = 'Python'
print('s[0]=',s[0])
print('s[-1]=',s[-1])
print('s[1:4]=',s[1:4])
print('s[:3]=',s[:3])
print('s[4:6]=',s[4:6])
print('s[5:6]=',s[5:6])
print('s[::2]=',s[::2])
print('Reverse:',s[::-1])
# Out:
# s[0]= P
# s[-1]= n
# s[1:4]= yth
# s[:3]= Pyt
# s[4:6]= on
# s[5:6]= n
# s[::2]= Pto
# Reverse: nohtyP

# %%
print(s[1:3])
# Out:
# yt

# %%
zainu= 'SOS|hamza zainudheenk|DataScienceandAnalytics|JULY2026|Morning|OFFLINE'
print(zainu[4:9]+zainu[10:21]+zainu[22]+zainu[26:27]+zainu[36]+zainu[46:49]+zainu[52:54]+zainu[55:57])
# Out:
# hamzazainudheenkDSAJUL26Mo

# %%
food='My name is Hamza Zainudheen k'
print(food.upper())
print(food.lower())
print(food.title())
print(food.capitalize())
print(food.swapcase())
print()
# Out:
# MY NAME IS HAMZA ZAINUDHEEN K
# my name is hamza zainudheen k
# My Name Is Hamza Zainudheen K
# My name is hamza zainudheen k
# mY NAME IS hAMZA zAINUDHEEN K

# %%
text='hello world'
print(len(text))
print(text.find('o'))
print(text.startswith('hello'))
print(text.isalpha())
print(text.split())
print(text.isalnum())
# Out:
# 11
# 4
# True
# False
# ['hello', 'world']
# False

# %%
player='cr7-is-good'
print(player.split('-'))
print(player.replace('cr7','messi'))
# Out:
# ['cr7', 'is', 'good']
# messi-is-good

# %%
s='spam and eggs'
print(s.replace('spam','ham'))
# Out:
# ham and eggs

# %%
orig = 'aeiou'
tr =str.maketrans('aeiou','12345')
print('translate:','education'.translate(tr))
# Out:
# translate: 2d5c1t34n

# %%
print('hamza\nzainu \nmanjeri \nkerala\nindia')
# Out:
# hamza
# zainu
# manjeri
# kerala
# india

# %%
print('hamz \t zainu')
# Out:
# hamz 	 zainu

# %%
#type conversion
a='abc123'
x='123'
y=int(x)
print(y)
print(type(y))
z=45
r=str(45)
print(type(r))
print(r)
# Out:
# 123
# <class 'int'>
# <class 'str'>
# 45

# %%
a=5
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1
# 25

# %%
fruites=['apple','banana','mango']
print(fruites)
# Out:
# ['apple', 'banana', 'mango']

# %%
for fruit in fruites:
    print(fruit)
# Out:
# apple
# banana
# mango

# %%
fruites=['apple','banana','mango']
print(fruites)
print('apple' in fruites)
print('apple'  not in  fruites)
# Out:
# ['apple', 'banana', 'mango']
# True
# False

# %%
x=10
y=26
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a=1300
b=130
print(id(a))
print(id(b))
print(a is  b)
print(x>3 and x<10)
print(x>3 or x<10)
print( not x<10)
# Out:
# 4442099664
# 4386829112
# False
# False
# True
# True
